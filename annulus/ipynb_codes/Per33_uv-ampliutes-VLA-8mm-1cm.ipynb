# %%
import astropy
import numpy as np
import matplotlib as mpl
import matplotlib.pyplot as plt
from astropy.io import ascii
from matplotlib.ticker import ScalarFormatter
import matplotlib.ticker as ticker

# %matplotlib inline
data13mmsub = ascii.read("Per33.8mm.uv.radial_averaged.proj.30klam.txt",names=['uvd','amp','e_amp','real','e_real','imag','e_imag','number'] )
data13mm = ascii.read("../Per33/Per33.8mm.uv.radial_averaged.proj.30klam.txt",names=['uvd','amp','e_amp','real','e_real','imag','e_imag','number'] )
data1cm=ascii.read("../Per33/Per33.1cm.uv.radial_averaged.proj.30klam.txt",names=['uvd','amp','e_amp','real','e_real','imag','e_imag','number'] )
data1cmsub=ascii.read("Per33.1cm.uv.radial_averaged.proj.30klam.txt",names=['uvd','amp','e_amp','real','e_real','imag','e_imag','number'] )

print data13mm
# Out:
#  uvd     amp     e_amp      real    e_real     imag    e_imag   number
# ------ -------- -------- --------- -------- --------- -------- --------
#   15.0  0.00305 0.000135  0.003049 0.000135  -6.2e-05 0.000135  48192.0
#   45.0 0.002684  9.6e-05  0.002663  9.6e-05  -0.00034  9.6e-05 104272.0
#   75.0 0.001308  7.5e-05  0.001307  7.5e-05   2.4e-05  7.6e-05 315792.0
#  105.0 0.000849  6.8e-05  0.000847  6.8e-05  -5.2e-05  6.8e-05 400272.0
#  135.0  0.00014  8.3e-05  0.000117  8.3e-05   7.6e-05  8.3e-05 265968.0
#  165.0 0.000246  8.6e-05  0.000241  8.6e-05   4.8e-05  8.6e-05 313536.0
#  195.0 0.000276  6.5e-05  0.000203  6.5e-05  0.000186  6.5e-05 454880.0
#  225.0 0.000389  7.7e-05  0.000363  7.7e-05   0.00014  7.7e-05 399118.0
#  255.0 0.000418  6.4e-05  0.000416  6.4e-05   4.2e-05  6.4e-05 460269.0
#  285.0 0.000518  7.7e-05  0.000518  7.7e-05    -7e-06  7.7e-05 387564.0
#    ...      ...      ...       ...      ...       ...      ...      ...
# ...

# %%
fig=plt.figure(figsize=(10,7))
ax = fig.add_subplot(111)
ax.set_xlim(0,4000.0)
#ax.set_ylim(-0.001,0.01)
lin1=ax.plot(data13mm['uvd'],data13mm['real'],marker='o',color='black',linestyle='none')
lin1err=ax.errorbar(data13mm['uvd'],data13mm['real'], yerr=data13mm['e_real'], fmt='o',color='black')
lin2=ax.plot(data13mmsub['uvd'],data13mmsub['real']/1000.0,marker='o',color='gray',linestyle='none')
lin2err=ax.errorbar(data13mmsub['uvd'],data13mmsub['real']/1000.0, yerr=data13mmsub['e_real']/1000.0, fmt='o',color='gray')

lin3=ax.plot(data1cm['uvd'],data1cm['real'],marker='o',color='black',linestyle='none')
lin3err=ax.errorbar(data1cm['uvd'],data1cm['real'], yerr=data1cm['e_real'], fmt='o',color='blue')
lin4=ax.plot(data1cmsub['uvd'],data1cmsub['real']/1000.0,marker='o',color='gray',linestyle='none')
lin4err=ax.errorbar(data1cmsub['uvd'],data1cmsub['real']/1000.0, yerr=data1cmsub['e_real']/1000.0, fmt='o',color='cyan')






ax.set_title('8mm Real Visibility Amplitudes', fontsize=18)
ax.set_ylabel('Real Visibility Amplitude (Jy)', fontsize=18)
ax.set_xlabel('Projected uv-distance (Klambda)', fontsize=18)

# %%
fig=plt.figure(figsize=(10,7))
ax = fig.add_subplot(111)
ax.set_xlim(0,500.0)
ax.set_ylim(-0.0010,0.0015)
lin1=ax.plot(data13mm['uvd'],data13mm['real'],marker='o',color='black',linestyle='none')
lin1err=ax.errorbar(data13mm['uvd'],data13mm['real'], yerr=data13mm['e_real'], fmt='o',color='black')
lin2=ax.plot(data13mmsub['uvd'],data13mmsub['real']/1000.0,marker='o',color='gray',linestyle='none')
lin2err=ax.errorbar(data13mmsub['uvd'],data13mmsub['real']/1000.0, yerr=data13mmsub['e_real']/1000.0, fmt='o',color='gray')

lin3=ax.plot(data1cm['uvd'],data1cm['real'],marker='o',color='black',linestyle='none')
lin3err=ax.errorbar(data1cm['uvd'],data1cm['real'], yerr=data1cm['e_real'], fmt='o',color='blue')
lin4=ax.plot(data1cmsub['uvd'],data1cmsub['real']/1000.0,marker='o',color='gray',linestyle='none')
lin4err=ax.errorbar(data1cmsub['uvd'],data1cmsub['real']/1000.0, yerr=data1cmsub['e_real']/1000.0, fmt='o',color='cyan')

# %%
fig=plt.figure(figsize=(10,7))
ax = fig.add_subplot(111)
ax.set_xlim(0,1500.0)

lin1=ax.plot(data13mm['uvd'],data13mm['imag'],marker='o',color='black',linestyle='none')
lin1err=ax.errorbar(data13mm['uvd'],data13mm['imag'], yerr=data13mm['e_imag'], fmt='o',color='black')
lin2=ax.plot(data13mmsub['uvd'],data13mmsub['imag'],marker='o',color='gray',linestyle='none')
lin2err=ax.errorbar(data13mmsub['uvd'],data13mmsub['imag'], yerr=data13mmsub['e_imag'], fmt='o',color='gray')

ax.set_title('8 mm Imaginary Visibility Amplitudes', fontsize=18)
ax.set_ylabel('Imaginary Visibility Amplitude (Jy)', fontsize=18)
ax.set_xlabel('Projected uv-distance (Klambda)', fontsize=18)

# %%
fig=plt.figure(figsize=(10,7))
ax = fig.add_subplot(111)
ax.set_xlim(10,1500.0)
#ax.set_ylim(0.01,1000.0)
lin1=ax.loglog(data13mm['uvd'],data13mm['real'],marker='o',color='black',linestyle='none')
lin1err=ax.errorbar(data13mm['uvd'],data13mm['real'], yerr=data13mm['e_real'], fmt='o',color='black')
lin2=ax.loglog(data13mmsub['uvd'],data13mmsub['real'],marker='o',color='gray',linestyle='none')
lin2err=ax.errorbar(data13mmsub['uvd'],data13mmsub['real'], yerr=data13mmsub['e_real'], fmt='o',color='gray')

ax.set_title('8 mm Real Visibility Amplitudes', fontsize=18)
ax.set_ylabel('Real Visibility Amplitude (Jy)', fontsize=18)
ax.set_xlabel('Projected uv-distance (Klambda)', fontsize=18)
for axis in [ax.xaxis, ax.yaxis]:
    axis.set_major_formatter(ScalarFormatter())
    ax.yaxis.set_major_formatter(ticker.FuncFormatter(lambda y,pos: ('{{:.{:1d}f}}'.format(int(np.maximum(-np.log10(y),0)))).format(y)))

# %%
data13mmsub = ascii.read("Per33.8mm.uv.radial_averaged.deproj.30klam.txt",names=['uvd','amp','e_amp','real','e_real','imag','e_imag','number'] )
data13mm = ascii.read("../Per33/Per33.8mm.uv.radial_averaged.deproj.30klam.txt",names=['uvd','amp','e_amp','real','e_real','imag','e_imag','number'] )

fig=plt.figure(figsize=(10,7))
ax = fig.add_subplot(111)
ax.set_xlim(0,1000.0)
#ax.set_ylim(0.01,1000.0)
lin1=ax.plot(data13mm['uvd'],data13mm['real'],marker='o',color='black',linestyle='none')
lin1err=ax.errorbar(data13mm['uvd'],data13mm['real'], yerr=data13mm['e_real'], fmt='o',color='black')
lin2=ax.plot(data13mmsub['uvd'],data13mmsub['real'],marker='o',color='gray',linestyle='none')
lin2err=ax.errorbar(data13mmsub['uvd'],data13mmsub['real'], yerr=data13mmsub['e_real'], fmt='o',color='gray')

ax.set_title('8 mm Real Visibility Amplitudes', fontsize=18)
ax.set_ylabel('Real Visibility Amplitude (Jy)', fontsize=18)
ax.set_xlabel('Deprojected uv-distance (Klambda)', fontsize=18)

# %%
fig=plt.figure(figsize=(10,7))
ax = fig.add_subplot(111)
ax.set_xlim(0,1000.0)
ax.set_ylim(-0.00250,0.0025)
lin1=ax.plot(data13mm['uvd'],data13mm['real'],marker='o',color='black',linestyle='none')
lin1err=ax.errorbar(data13mm['uvd'],data13mm['real'], yerr=data13mm['e_real'], fmt='o',color='black')
lin2=ax.plot(data13mmsub['uvd'],data13mmsub['real'],marker='o',color='gray',linestyle='none')
lin2err=ax.errorbar(data13mmsub['uvd'],data13mmsub['real'], yerr=data13mmsub['e_real'], fmt='o',color='gray')

ax.set_title('1.3mm Real Visibility Amplitudes', fontsize=18)
ax.set_ylabel('Real Visibility Amplitude (Jy)', fontsize=18)
ax.set_xlabel('Projected uv-distance (Klambda)', fontsize=18)
